# %%
# importar todas las paqueterias necesarias 
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pandas as pd
import squarify

# %%
# son muchos datos y es necesario que las columnas sean visibles 
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# las columnas a veces traen información muy extensa que es importante ver
pd.set_option('display.max_colwidth', None)

# %%
# el diccionario de datos nos permite saber el significado de las columnas
# lo convierto en Data Frame para que sea más fácil de visualizar
# el encoding es por los caracteres especiales del español y la memoria porque es extenso
# este diccionario viene en partes
diccionarioP3= pd.read_csv('Datos (CNGSPSPE) 2020/diccionario_de_datos_m3s1p3_cngspspe2020.csv', 
                         encoding='utf-8-sig', 
                         low_memory=False
)
diccionarioP3
# Out:
#      COLUMNA  \
# 0  entidad_a
# 1    numeral
# 2    nombre1
# 3    rensnn1
# 4       anio
#
#                                                                                DESCRIPCION  \
# 0                                                                       Entidad federativa
# 1  Identificador o numeral del orden que guarda cada registro capturado dentro de la lista
# 2                                                     Nombre de los centros penitenciarios
# 3                         Operación bajo el esquema de contrato de prestación de servicios
# 4       Año en el que entró en operación el esquema de contrato de prestación de servicios
#
#       ORIGEN TIPO_DATO  LONGITUD CODIGO_VALIDO
# 0  SECC I. 3  Numérico         2       1 al 99
# 1  SECC I. 3  Carácter         4        0-5000
# 2  SECC I. 3  Carácter       500           NaN
# 3  SECC I. 3  Numérico         2       0 al 98
# 4  SECC I. 3       NaN         4           NaN

# %% [markdown]
# Segun este diccionario la variable que nos interesa es rensnn1 para saber si los centros penitenciarios operan bajo el esquema d econtrato de prestación de servicios

# %%
# valores de rensnn1
valores_rensnn1= pd.read_csv('Datos (CNGSPSPE) 2020/rensnn1_cngspspe2020.csv', 
                         encoding='utf-8-sig', 
                         low_memory=False
)
valores_rensnn1
# Out:
#    rensnn1                                 descrip
# 0        0                               No aplica
# 1        1                                      Sí
# 2        2                                      No
# 3        9                              No se sabe
# 4       97  No cuenta con elementos para responder
# 5       98               Información no disponible

# %%
# df = Data Frame
df_exploratorioP3= pd.read_csv('Datos (CNGSPSPE) 2020/m3s1p3_cngspspe2020.csv',
    encoding='utf-8-sig',
    low_memory=False
)
df_exploratorioP3['rensnn1'].value_counts()
# Out:
# rensnn1
# 2    220
# 1     29
# 9      5
# Name: count, dtype: int64

# %% [markdown]
# De acuerdo con esto, hay 29 centros que operan bajo esta figura y 5 que no se sabe, veamos cuale son

# %%
df_exploratorioP3[df_exploratorioP3['rensnn1']!=2]
# Out:
#      entidad_a  numeral  \
# 4            2        1
# 5            2        2
# 6            2        3
# 7            2        4
# 8            2        5
# 56           9       11
# 57           9       12
# 59          10        1
# 60          10        2
# 61          10        3
# 85          13        1
# 87          13        3
# 92          13        8
# 93          13        9
# 94          13       10
# 95          13       11
# 96          13       12
# 97          14        1
# 98          14        2
# 99          14        3
# 100         14        4
# 101         14        5
# 102         14        6
# 103         14        7
# 104         14        8
# 105         14        9
# 106         14       10
# 107         14       11
# 108         14       12
# 159         20        5
# 162         20        8
# 173         23        1
# 174         23        2
# 175         23        3
#
#                                                               nombre1  \
# ...

# %% [markdown]
# Hagamos un Data frame con solo los que sabemos que son CPS

# %%
Df_CPS = df_exploratorioP3[df_exploratorioP3['rensnn1']==1]
Df_CPS
# Out:
#      entidad_a  numeral  \
# 56           9       11
# 57           9       12
# 59          10        1
# 60          10        2
# 61          10        3
# 85          13        1
# 87          13        3
# 92          13        8
# 93          13        9
# 94          13       10
# 95          13       11
# 96          13       12
# 97          14        1
# 98          14        2
# 99          14        3
# 100         14        4
# 101         14        5
# 102         14        6
# 103         14        7
# 104         14        8
# 105         14        9
# 106         14       10
# 107         14       11
# 108         14       12
# 159         20        5
# 162         20        8
# 173         23        1
# 174         23        2
# 175         23        3
#
#                                                               nombre1  \
# 56                        CENTRO VARONIL DE SEGURIDAD PENITENCIARIA I
# ...

# %% [markdown]
# Ahora vamos en que estado estan

# %%
valores_entidad_a = pd.read_csv('Datos (CNGSPSPE) 2020/entidad_a_cngspspe2020.csv', 
                         encoding='utf-8-sig', 
                         low_memory=False
)
valores_entidad_a
# Out:
#     entidad_a                          descrip
# 0           1                   Aguascalientes
# 1           2                  Baja California
# 2           3              Baja California Sur
# 3           4                         Campeche
# 4           5             Coahuila de Zaragoza
# 5           6                           Colima
# 6           7                          Chiapas
# 7           8                        Chihuahua
# 8           9                 Ciudad de México
# 9          10                          Durango
# 10         11                       Guanajuato
# 11         12                         Guerrero
# 12         13                          Hidalgo
# 13         14                          Jalisco
# 14         15                           México
# 15         16              Michoacán de Ocampo
# 16         17                          Morelos
# 17         18                          Nayarit
# 18         19                       Nuevo León
# ...

# %%
Df_CPS = Df_CPS.merge(
    valores_entidad_a[['entidad_a', 'descrip']],
    on='entidad_a',
    how='left'
)

# %%
Df_CPS['descrip'].value_counts()
# Out:
# descrip
# Jalisco             12
# Hidalgo              7
# Quintana Roo         3
# Durango              3
# Ciudad de México     2
# Oaxaca               2
# Name: count, dtype: int64

# %%
Df_CPS
# Out:
#     entidad_a  numeral  \
# 0           9       11
# 1           9       12
# 2          10        1
# 3          10        2
# 4          10        3
# 5          13        1
# 6          13        3
# 7          13        8
# 8          13        9
# 9          13       10
# 10         13       11
# 11         13       12
# 12         14        1
# 13         14        2
# 14         14        3
# 15         14        4
# 16         14        5
# 17         14        6
# 18         14        7
# 19         14        8
# 20         14        9
# 21         14       10
# 22         14       11
# 23         14       12
# 24         20        5
# 25         20        8
# 26         23        1
# 27         23        2
# 28         23        3
#
#                                                              nombre1  rensnn1  \
# 0                        CENTRO VARONIL DE SEGURIDAD PENITENCIARIA I        1
# 1                       CENTRO VARONIL DE SEGURIDAD PENITENCIARIA II        1
# ...

# %%
Df_CPS.drop(columns=['entidad_a'], inplace=True)

# %% [markdown]
# Estos son los centros que se manejan bajo CPS

# %%
Df_CPS
# Out:
#                                                              nombre1  anio  \
# 0                        CENTRO VARONIL DE SEGURIDAD PENITENCIARIA I  2015
# 1                       CENTRO VARONIL DE SEGURIDAD PENITENCIARIA II  2015
# 2                                                       CERESO NO. 1  1970
# 3                                                CE.DI.RE.SO.  NO. 1  2001
# 4                                                CE.DI.RE.SO.  NO. 2  2007
# 5                                                            ACTOPAN  2007
# 6                                                           HUASTECA  2001
# 7                                                            MOLANGO  1990
# 8                                                            PACHUCA  1975
# 9                                                            TENANGO  1989
# 10                                                              TULA  1996
# ...

# %% [markdown]
# A partir de esto podemos ver el tipo de centro penitenciario, su clasificación o división del centro penitenciario y el modelo arquitectónico penitenciario

# %%
diccionarioP2= pd.read_csv('Datos (CNGSPSPE) 2020/diccionario_de_datos_m3s1p2_cngspspe2020.csv', 
                         encoding='utf-8-sig', 
                         low_memory=False
)
diccionarioP2
# Out:
#       COLUMNA  \
# 0   entidad_a
# 1     numeral
# 2     nombre1
# 3  centpeni_a
# 4  clascent_a
# 5  modarqui_a
#
#                                                                                DESCRIPCION  \
# 0                                                                       Entidad federativa
# 1  Identificador o numeral del orden que guarda cada registro capturado dentro de la lista
# 2                                                     Nombre de los centros penitenciarios
# 3                                                             Tipo de centro penitenciario
# 4                                        Clasificación o división del centro penitenciario
# 5                                                      Modelo arquitectónico penitenciario
#
#       ORIGEN TIPO_DATO  LONGITUD CODIGO_VALIDO
# 0  SECC I. 2  Numérico         2       1 al 99
# 1  SECC I. 2  Carácter         4        0-5000
# 2  SECC I. 2  Carácter       500           NaN
# ...

# %%
valores_centpeni_a = pd.read_csv('Datos (CNGSPSPE) 2020/centpeni_a_cngspspe2020.csv', 
                         encoding='utf-8-sig', 
                         low_memory=False
)
valores_centpeni_a
# Out:
#     centpeni_a                                                descrip
# 0            1             Centro de Readaptación Social para hombres
# 1            2             Centro de Readaptación Social para mujeres
# 2            3                    Centro de Readaptación Social mixto
# 3            4                                Reclusorio para hombres
# 4            5                                Reclusorio para mujeres
# 5            6                                       Reclusorio mixto
# 6            7                             Penitenciaría para hombres
# 7            8                             Penitenciaría para mujeres
# 8            9                                    Penitenciaría mixta
# 9           10                                    Cárcel para hombres
# 10          11                                    Cárcel para mujeres
# 11          12                                           Cárcel mixta
# ...

# %%
valores_clascent_a = pd.read_csv('Datos (CNGSPSPE) 2020/clascent_a_cngspspe2020.csv', 
                         encoding='utf-8-sig', 
                         low_memory=False
)
valores_clascent_a
# Out:
#    clascent_a                                     descrip
# 0           1                            Seguridad máxima
# 1           2                             Seguridad media
# 2           3                            Seguridad mínima
# 3           4  Hospital psiquiátrico y/o para infecciosos
# 4           5                         Institución abierta
# 5           6                           Sin clasificación
# 6           7                                        Otro
# 7           9                                  No se sabe

# %%
valores_modarqui_a = pd.read_csv('Datos (CNGSPSPE) 2020/modarqui_a_cngspspe2020.csv', 
                         encoding='utf-8-sig', 
                         low_memory=False
)
valores_modarqui_a
# Out:
#    modarqui_a           descrip
# 0           1         Panóptico
# 1           2            Radial
# 2           3  Partido paralelo
# 3           4           Podular
# 4           5              Otro
# 5           9        No se sabe

# %%
df_p2= pd.read_csv('Datos (CNGSPSPE) 2020/m3s1p2_cngspspe2020.csv', 
                         encoding='utf-8-sig', 
                         low_memory=False
)
df_p2.head()
# Out:
#    entidad_a  numeral                                           nombre1  \
# 0          1        1       CENTRO DE REINSERCION SOCIAL AGUASCALIENTES
# 1          1        2             CENTRO DE REINSERCION SOCIAL EL LLANO
# 2          1        3         CENTRO DE REINSERCION SOCIAL PARA MUJERES
# 3          1        4  CENTRO DE REINSERCION SOCIAL DE MINIMA SEGURIDAD
# 4          2        1             CENTRO DE REINSERCIÓN SOCIAL MEXICALI
#
#    centpeni_a  clascent_a  modarqui_a
# 0           1           2           5
# 1           1           2           5
# 2           2           2           5
# 3           3           5           5
# 4           3           2           9

# %%
Df_CPS = Df_CPS.merge(
    df_p2[['nombre1', 'centpeni_a', 'clascent_a', 'modarqui_a']],
    on='nombre1',
    how='left'
)
Df_CPS
# Out:
#                                                              nombre1  anio  \
# 0                        CENTRO VARONIL DE SEGURIDAD PENITENCIARIA I  2015
# 1                       CENTRO VARONIL DE SEGURIDAD PENITENCIARIA II  2015
# 2                                                       CERESO NO. 1  1970
# 3                                                CE.DI.RE.SO.  NO. 1  2001
# 4                                                CE.DI.RE.SO.  NO. 2  2007
# 5                                                            ACTOPAN  2007
# 6                                                           HUASTECA  2001
# 7                                                            MOLANGO  1990
# 8                                                            PACHUCA  1975
# 9                                                            TENANGO  1989
# 10                                                              TULA  1996
# ...

# %% [markdown]
# Como ahora hay varias columnas por renombrar crearemos una funcion que lo haga

# %%
def reemplazar_y_renombrar(df_principal, columna_codigo, df_valores, nuevo_nombre):
    # Crea el diccionario {código: descripción}
    mapeo = dict(zip(df_valores[columna_codigo], df_valores['descrip']))
    
    # Reemplaza los códigos por su significado
    df_principal[columna_codigo] = df_principal[columna_codigo].map(mapeo)
    
    # Renombra la columna a algo significativo
    df_principal = df_principal.rename(columns={columna_codigo: nuevo_nombre})
    
    return df_principal

# %%
Df_CPS = reemplazar_y_renombrar(Df_CPS, 'modarqui_a', valores_modarqui_a, 'Modelo arquitectónico penitenciario')
Df_CPS
# Out:
#                                                              nombre1  anio  \
# 0                        CENTRO VARONIL DE SEGURIDAD PENITENCIARIA I  2015
# 1                       CENTRO VARONIL DE SEGURIDAD PENITENCIARIA II  2015
# 2                                                       CERESO NO. 1  1970
# 3                                                CE.DI.RE.SO.  NO. 1  2001
# 4                                                CE.DI.RE.SO.  NO. 2  2007
# 5                                                            ACTOPAN  2007
# 6                                                           HUASTECA  2001
# 7                                                            MOLANGO  1990
# 8                                                            PACHUCA  1975
# 9                                                            TENANGO  1989
# 10                                                              TULA  1996
# ...

# %%
Df_CPS = reemplazar_y_renombrar(Df_CPS, 'centpeni_a', valores_centpeni_a, 'Tipo de centro penitenciario')
Df_CPS = reemplazar_y_renombrar(Df_CPS, 'clascent_a', valores_clascent_a, 'Clasificación o división del centro penitenciario')
Df_CPS
# Out:
#                                                              nombre1  anio  \
# 0                        CENTRO VARONIL DE SEGURIDAD PENITENCIARIA I  2015
# 1                       CENTRO VARONIL DE SEGURIDAD PENITENCIARIA II  2015
# 2                                                       CERESO NO. 1  1970
# 3                                                CE.DI.RE.SO.  NO. 1  2001
# 4                                                CE.DI.RE.SO.  NO. 2  2007
# 5                                                            ACTOPAN  2007
# 6                                                           HUASTECA  2001
# 7                                                            MOLANGO  1990
# 8                                                            PACHUCA  1975
# 9                                                            TENANGO  1989
# 10                                                              TULA  1996
# ...
